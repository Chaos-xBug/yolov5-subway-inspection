# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
path="/content/drive/MyDrive/new_siamese"
os.chdir(path)
os.listdir(path)
# Out:
# ['predict.py',
#  '.idea',
#  'nets',
#  'utils',
#  'model_data',
#  'siamese.py',
#  'datasets',
#  'logs',
#  'train.py',
#  'test_siamese.ipynb']

# %%
# !python train.py
# Out:
# 运行了load_dataset
# 排序前： ['datasets/same/123-check.jpg', 'datasets/same/123-orign.jpg', 'datasets/same/55-check.jpg', 'datasets/same/55-orign.jpg', 'datasets/same/80-check.jpg']
# 排序后： ['datasets/same/0-orign.jpg', 'datasets/same/0-check.jpg', 'datasets/same/1-orign.jpg', 'datasets/same/1-check.jpg', 'datasets/same/2-check.jpg', 'datasets/same/2-orign.jpg', 'datasets/same/3-check.jpg', 'datasets/same/3-orign.jpg', 'datasets/same/4-check.jpg', 'datasets/same/4-orign.jpg', 'datasets/same/5-orign.jpg', 'datasets/same/5-check.jpg', 'datasets/same/6-check.jpg', 'datasets/same/6-orign.jpg', 'datasets/same/7-check.jpg', 'datasets/same/7-orign.jpg', 'datasets/same/8-orign.jpg', 'datasets/same/8-check.jpg', 'datasets/same/9-check.jpg', 'datasets/same/9-orign.jpg']
# 排序前： ['datasets/diff/44-orgin.jpg', 'datasets/diff/24-check.jpg', 'datasets/diff/12-orgin.jpg', 'datasets/diff/9-orgin.jpg', 'datasets/diff/43-orgin.jpg']
# ...

# %%
# !python predict.py
# Out:
# Loading weights into state dict...
# /content/drive/MyDrive/new_siamese/logs/ep015-loss0.034-val_loss0.014.pth model loaded.
# Input image_1 filename:/content/drive/MyDrive/new_siamese/datasets/diff/137-check.jpg
# Input image_2 filename:/content/drive/MyDrive/new_siamese/datasets/diff/137-orgin.jpg
# <Figure size 640x480 with 2 Axes>
# tensor([5.1047e-12], device='cuda:0')
# Input image_1 filename:/content/drive/MyDrive/new_siamese/datasets/diff/188-check.jpg
# Input image_2 filename:/content/drive/MyDrive/new_siamese/datasets/diff/188-orgin.jpg
# <Figure size 640x480 with 2 Axes>
# tensor([3.2931e-11], device='cuda:0')
# Input image_1 filename:/content/drive/MyDrive/new_siamese/datasets/diff/188-orgin.jpg
# Input image_2 filename:/content/drive/MyDrive/new_siamese/datasets/diff/188-orgin.jpg
# <Figure size 640x480 with 2 Axes>
# tensor([0.5309], device='cuda:0')
# Input image_1 filename:/content/drive/MyDrive/new_siamese/datasets/diff/198-orgin.jpg
# ...
